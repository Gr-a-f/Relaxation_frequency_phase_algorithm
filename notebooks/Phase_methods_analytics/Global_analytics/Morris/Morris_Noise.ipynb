# %%
# %load_ext autoreload 
# %autoreload 2

import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../../.."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(os.path.join(os.getcwd(), ".."))

import math
import numpy as np
import pandas as pd
from numpy import array
from numpy import array, arange, abs as np_abs
from numpy.fft import rfft, rfftfreq
from math import sin, pi
from scipy import signal
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import random
from SALib.sample import morris as morris_sampler
from SALib.analyze import morris as morris_analyzer
from IPython.display import clear_output

import importlib
import model as md
import view as vw

importlib.reload(md)
importlib.reload(vw)

from model.relevant_methods import phase_methods
# Out:
# c:\Users\Артем\Desktop\Вуз\Аспирантура\Диссертация\Алгоритм\Relaxation_frequency_phase_algorithm\notebooks\Phase_methods_analytics\Global_analytics\Morris\..

# %% [markdown]
# # Обычный Моррис c Шумом

# %%
def generate_Morris_new(problem,phase_methods, N=6000, num_levels=100):
# 2) Генерация траекторий
    param_values = morris_sampler.sample(problem, N, num_levels=100)
    i=0
    from tqdm import tqdm
    Y_mass = []
    Param_mass=[]
    for i in range(0, len(phase_methods), 1):
        Y = []
        P=[]

        # tqdm оборачивает param_values и показывает прогресс
        for j, p in enumerate(tqdm(param_values, desc=f"Метод {phase_methods[i].__name__}", unit=" шага")):
            F, phase_real, fs_mult, duration_T, gen_unstable, bits, SNR = p

            duration = duration_T / F
            Hz_unstable=gen_unstable*F*10e-6
            fs = F * fs_mult

            t = np.linspace(0, duration, int(duration * fs))

            phase = md.generate_common_phase(
                t,
                F,
                gen_unstable,
                phase0_deg=0
            )

            # 2. Сигналы с заданной фазовой разницей
            U, I = md.generate_signals_from_phase(
                phase,
                phase_diff_deg=phase_real
            )

            U = md.add_SNR(U, SNR)
            I = md.add_SNR(I, SNR)

            U=md.adc_quantize(U,int(bits),1)
            I=md.adc_quantize(I,int(bits),1)

            phase_mes = phase_methods[i](t, U, I, F)
            phase_error = abs(phase_mes) - abs(phase_real)

            Y.append(abs(phase_error))
            P.append(p)

        Y_mass.append(np.array(Y))
        Param_mass.append(P)
    return Y_mass, Param_mass, param_values

# %%
import os
import pickle
import hashlib
import numpy as np

def compute_hash(param_values):
    """Создаёт уникальный хеш для массива параметров"""
    return hashlib.md5(param_values.tobytes()).hexdigest()


def save_morris_data(filename, Y_mass, Param_mass, param_values):
    new_hash = compute_hash(param_values)

    # если файла нет — просто сохраняем
    if not os.path.exists(filename):
        with open(filename, "wb") as f:
            pickle.dump({
                "Y_mass": Y_mass,
                "Param_mass": Param_mass,
                "param_values": param_values,
                "hash": new_hash
            }, f)
        print("Новый файл")
        return

    # если файл есть — проверяем дубликаты
    existing_hashes = set()

    with open(filename, "rb") as f:
        while True:
            try:
                data = pickle.load(f)
                if "hash" in data:
                    existing_hashes.add(data["hash"])
            except EOFError:
                break

    if new_hash in existing_hashes:
        print("Сохранение пропущено")
        return

    # если не дубликат — сохраняем
    with open(filename, "ab") as f:
        pickle.dump({
            "Y_mass": Y_mass,
            "Param_mass": Param_mass,
            "param_values": param_values,
            "hash": new_hash
        }, f)

    print("Данные добавлены")

# %%
def load_morris_data(filename):
    Y_mass_all = None
    Param_mass_all = None
    param_values_all = []

    if not os.path.exists(filename):
        return [], [], np.array([])

    with open(filename, "rb") as f:
        while True:
            try:
                data = pickle.load(f)

                if Y_mass_all is None:
                    Y_mass_all = data["Y_mass"]
                    Param_mass_all = data["Param_mass"]
                else:
                    for i in range(len(Y_mass_all)):
                        Y_mass_all[i] = np.concatenate([Y_mass_all[i], data["Y_mass"][i]])
                        Param_mass_all[i].extend(data["Param_mass"][i])

                param_values_all.append(data["param_values"])

            except EOFError:
                break

    param_values_all = np.vstack(param_values_all)

    return Y_mass_all, Param_mass_all, param_values_all

# %%
# 1) Определяем параметры
problem = {
    'num_vars': 7,
    'names': ['F', 'φ', 'FsM','DT','GU','Bit','SNR'],
    'bounds': [
        [300e3, 500e3],     # F
        [1,179],             # phase
        [3, 20],            # fs_mult
        [2, 200],           # duration_T
        [0.01,10],             # generator instability
        [5,35],                  #bits
        [30,100]                  #SNR dB
    ]
}

# %%
Y_mass, Param_mass, param_values = generate_Morris_new(problem,phase_methods,3000)
save_morris_data("Morris_data_noise",Y_mass, Param_mass,param_values)
# Out:
# Метод get_phase_LI: 100%|██████████| 24000/24000 [00:07<00:00, 3324.42 шага/s]
# Новый файл

# %%
Y_mass_all, Param_mass_all,param_values_all=load_morris_data("Morris_data_noise")
len(Y_mass_all[0])
# Out:
# 24000

# %%
# Очистка названий
def clean_name(func):
    return func.__name__.replace("get_phase_", "").replace("get_phase", "")

# %%
method_names = [m.__name__ for m in phase_methods]
param_names = problem['names']

# Цвета и маркеры
colors = ['b', 'r', 'g', 'm', 'c', 'y', 'k']
markers = ['o', 's', 'D', '^', 'v', '*', 'P', 'X']

# для вывода в exel
rows = []

n_methods = len(phase_methods)
n_cols = 3
n_rows = math.ceil(n_methods / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(7, 7))
axes = axes.flatten()

# Список для хранения "фейковых" точек (для легенды)
legend_handles = []

for i, method in enumerate(phase_methods):
    Si = morris_analyzer.analyze(problem, param_values_all, Y_mass_all[i])
    

    mu = np.asarray(Si['mu'], dtype=float).copy()
    sigma = np.asarray(Si['sigma'], dtype=float).copy()

    for j, param in enumerate(problem['names']):
        rows.append({
            'Method': clean_name(method),
            'Parameter': param,
            'mu': mu[j],
            'sigma': sigma[j]
        })

    ax = axes[i]

    for j, name in enumerate(param_names):
        sc = ax.scatter(mu[j], sigma[j], color=colors[j], marker=markers[j % len(markers)])

        #sc = ax.scatter(
        #mu[j], 
        #sigma[j], 
        #marker=markers[j % len(markers)],
        #color='black',          # Цвет контура
        #facecolors='white',     # Белая заливка внутри (чтобы точки не сливались)
        #edgecolors='black',     # Четкий контур
        #s=40,                   # Размер точки (можно чуть уменьшить)
        #linewidths=1.2          # Толщина контура
        #)
        
        # Только при первом методе наполняем legend_handles
        if i == 0:
            legend_handles.append(sc)

        # Границы оси X основаны только на му
    mu_min, mu_max = mu.min(), mu.max()
    pad = (mu_max - mu_min) * 0.1 if mu_max != mu_min else 0.1  # запас
  
    lim_x = [mu_min - pad, mu_max + pad]

    # Границы оси Y (σ >= 0)
    sigma_max = sigma.max()
    ax.set_ylim([0, sigma_max * 1.1])

    # Диагональные линии
    x_line = np.linspace(lim_x[0], lim_x[1], 100)
    ax.plot(x_line, x_line, '--', linewidth=0.7, color='k')
    ax.plot(x_line, -x_line, '--', linewidth=0.7, color='k')

    ax.set_xlim(lim_x)
    ax.set_ylim(bottom=1e-6, top=sigma.max() * 1.1)

    ax.set_title(clean_name(phase_methods[i]), fontsize=12)
    # Убираем стандартные подписи
    ax.set_xlabel('')
    ax.set_ylabel('')

    # σ — сверху оси Y
    # σ чуть над осью
    ax.text(0.0, 1.02, 'σ', transform=ax.transAxes,
        ha='left', va='bottom', fontsize=12)

    # μ чуть правее оси
    ax.text(1.06, 0.0, 'μ', transform=ax.transAxes,
        ha='left', va='bottom', fontsize=12)
    ax.grid(True, alpha=0.3)

# Удаляем лишнюю пустую ось (так как графиков 5, а мест 6)
for j in range(len(phase_methods), len(axes)):
    fig.delaxes(axes[j])

# Общая легенда
fig.legend(
    legend_handles, param_names,
    loc='lower center',         # перенести вниз
    ncol=1,                     # два ряда (5 параметров > 3 => автоматически сделает новый ряд) 
    bbox_to_anchor=(0.45, 0.05),  # смещение ниже графиков
    fontsize=10
)

#fig.suptitle('Диаграмма чувствительности (Метод Морриса)', fontsize=14)
fig.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import pandas as pd
import numpy as np
import openpyxl

# ---------- IEEE formatter ----------
def fmt_ieee(x, sig=3):
    if pd.isna(x):
        return ""

    if x == 0:
        return "0"

    exp = int(np.floor(np.log10(abs(x))))

    if -2 <= exp <= 2:
        return f"{x:.{sig-1}f}".rstrip('0').rstrip('.')

    mant = x / 10**exp
    mant_str = f"{mant:.{sig-1}f}".rstrip('0').rstrip('.')
    return f"{mant_str}e{exp}"

# ---------- top-3 bold ----------
def highlight_top3(row):
    # строка сейчас строковая → возвращаемся к float
    vals = row.astype(float)

    # берём модуль
    abs_vals = vals.abs()

    # индексы топ-3 по |μ|
    top3 = abs_vals.nlargest(3).index

    return [
        'font-weight: bold' if col in top3 else ''
        for col in row.index
    ]


# ---------- DataFrame ----------
df = pd.DataFrame(rows)

df_mu = df.pivot_table(
    index='Method',
    columns='Parameter',
    values='mu'
)

# порядок
df_mu = df_mu.reindex(columns=problem['names'])
df_mu = df_mu.reindex(index=[clean_name(m) for m in phase_methods])

# превращаем числа в строки ДО Excel
df_mu_str = df_mu.applymap(fmt_ieee)

styled = (
    df_mu_str
    .style
    .apply(highlight_top3, axis=1)
)

styled.to_excel(
    "morris_mu_highlighted.xlsx",
    engine="openpyxl"
)
# Out:
# C:\Users\Артем\AppData\Local\Temp\ipykernel_19304\1366373401.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_mu_str = df_mu.applymap(fmt_ieee)

# %%
# === ВЫВОД ВСЕХ ЧИСЕЛ С НАЗВАНИЯМИ ===
print("\n--- Все значения параметров по методам ---")
for method_name, row in df_mu.iterrows():
    # Собираем пары "Параметр: Значение" для всей строки
    pairs = [f"{param}: {val}" for param, val in row.items()]
    
    # Склеиваем их через запятую и выводим
    print(f"{method_name} -> {', '.join(pairs)}")
print("-" * 40, "\n")
# Out:
# --- Все значения параметров по методам ---
# MP -> F: 0.00763438733454674, φ: 1.514820555375747, FsM: -2.757520769669186, DT: -0.14277189547897293, GU: 0.0068935411482886665, Bit: -0.5559145142114905, SNR: -0.771985002166836
# ZCRR -> F: 0.0012161412708287809, φ: -0.14934242056117206, FsM: -1.8233617870071863, DT: 0.034049218148005475, GU: 0.00491182922985827, Bit: -0.062219859858765394, SNR: -0.010668571572496371
# FFT -> F: -0.0004598544009403812, φ: 0.046978614742523746, FsM: -0.1948335168980957, DT: -0.21750635296881682, GU: -0.000800983322009663, Bit: -0.0060766132928541695, SNR: -0.009744820478168175
# HB -> F: -0.0019462894966384614, φ: -0.000979621479726625, FsM: -0.015050676626499527, DT: -0.022006774136051007, GU: 0.0005858136626809955, Bit: -0.07537257987920391, SNR: -0.05862460726336794
# XCOR -> F: 0.022426310172158747, φ: 0.4761457795420181, FsM: -0.646630622851376, DT: -0.16861743824432804, GU: -0.00021945517374848388, Bit: -0.05057759197960733, SNR: -0.08350339325027795
# LI -> F: 0.002668128029863453, φ: 0.05970455286360726, FsM: -0.13265955486003075, DT: 0.10917708905908849, GU: 0.00026117924595642396, Bit: 0.004073797010774246, SNR: 0.02781371107990176
# SWFR -> F: 0.0002124622314124771, φ: 0.0011066890813293566, FsM: -0.011066046011249473, DT: -0.016604788080305133, GU: -0.0016947033962847655, Bit: -0.010608291283230013, SNR: -0.03227095564181807
# ----------------------------------------

# %% [markdown]
# # Локальный

# %%
def binned_mean(X, Y, bins):
    bin_idx = np.digitize(X, bins)

    X_bin = []
    Y_bin = []

    for b in range(1, len(bins)):
        mask = bin_idx == b
        if np.any(mask):
            X_bin.append(X[mask].mean())
            Y_bin.append(Y[mask].mean())

    return np.array(X_bin), np.array(Y_bin)

# %%
# ===== настройки =====
Param_index = problem['names'].index('SNR')   # любой параметр 'F', 'φ', 'FsM','DT','GU','Bit'
param_name = problem['names'][Param_index]

n_bins = 25
colors = plt.cm.tab10(np.linspace(0, 1, len(phase_methods)))

plt.figure(figsize=(6, 4))

saturation_points = {}

# ===== общий диапазон bins =====
all_X = []
for m in range(len(phase_methods)):
    P = np.asarray(Param_mass_all[m])
    all_X.append(P[:, Param_index])

all_X = np.concatenate(all_X)
bins = np.linspace(all_X.min(), all_X.max(), n_bins + 1)

# ===== цикл по методам =====
for m, method in enumerate(phase_methods):
    P = np.asarray(Param_mass_all[m])
    Y = np.asarray(Y_mass_all[m])

    X_raw = P[:, Param_index]
    Y_raw = Y

    # binning
    X_bin, Y_bin = binned_mean(X_raw, Y_raw, bins)

    # нормализация (для 95%)
    Y_norm = (Y_bin - Y_bin.min()) / (Y_bin.max() - Y_bin.min())

    # точка 95% уменьшения
    idx = np.where(Y_norm <= 0.05)[0]
    if len(idx) > 0:
        x95 = X_bin[idx[0]]
        saturation_points[method.__name__] = x95
        #plt.axvline(x95, color=colors[m], linestyle='--', alpha=0.3)
    else:
        saturation_points[method.__name__] = None

    # график
    plt.plot(
        X_bin,
        Y_bin,
        #marker='o',
        color=colors[m],
        label=clean_name(method)
    )
    

# ===== оформление =====
plt.yscale('log')
plt.xlabel(param_name)
plt.ylabel('Mean phase error')
plt.grid(True, alpha=0.3)
plt.legend(fontsize=9)
plt.tight_layout()
plt.show()

# %%
print(f'95% saturation points for parameter "{param_name}":\n')
for k, v in saturation_points.items():
    if v is not None:
        print(f'{k:25s}: {v:.4g}')
    else:
        print(f'{k:25s}: not reached')
# Out:
# 95% saturation points for parameter "SNR":
#
# get_phase_LI             : 79.14

# %%
import pandas as pd
import numpy as np

rows_sat = []

for method_name, value in saturation_points.items():
    rows_sat.append({
        'Parameter': param_name,
        'Method': method_name,
        'Saturation_95': value if value is not None else np.nan
    })

df_sat = pd.DataFrame(rows_sat)

df_sat_fmt = df_sat.copy()
df_sat_fmt['Saturation_95'] = df_sat_fmt['Saturation_95'].apply(fmt_ieee)

df_sat_fmt.to_excel(
    "morris_95_saturation.xlsx",
    index=False
)

# %% [markdown]
# # Тест других метрик по тем же данным

# %%
from scipy.stats import pearsonr

for m, method in enumerate(phase_methods):
    P = np.asarray(Param_mass_all[m])
    Y = np.asarray(Y_mass_all[m])

    X_raw = P[:, Param_index]
    Y_raw = Y

    corr, p_value = pearsonr(X_raw, Y_raw)
    print(f"Коэффициент: {corr}, p-value: {p_value}")
# Out:
# Коэффициент: 0.0044214826201796455, p-value: 0.49338127030508744

# %% [markdown]
# # Доп графики по обычному Моррису

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import EngFormatter


method_names = [clean_name(m) for m in phase_methods]
param_names = problem['names']

# Вычисляем mu*
mu_stars = []
for k in range(len(phase_methods)):
    Si = morris_analyzer.analyze(problem, param_values_all, Y_mass_all[k], print_to_console=False)
    mu_stars.append(Si['mu_star'])
mu_stars = np.array(mu_stars)

# --- Построение графика ---
fig, ax = plt.subplots(figsize=(7, 10))
y = np.arange(len(param_names))
height = 0.15

# Убираем все рамки
for spine in ax.spines.values():
    spine.set_visible(False)

min_val = np.max([np.min(mu_stars), 1e-6])
# Рисуем бары
for i in range(len(method_names)):
    bar_positions = y + i * height
    bars = ax.barh(bar_positions, mu_stars[i], height, label=method_names[i])

    for bar in bars:
        value = bar.get_width()
        offset = 1.1  # множитель для смещения справа

        # 📌 Гарантированно правее оси Y
        if value <= min_val:
            text_x = min_val * 1.5
        else:
            text_x = value * offset

        ax.text(
            text_x,
            bar.get_y() + bar.get_height() / 2,
            f"{value:.2e}",
            va='center'
        )

# Оформление
ax.set_yticks(y + height * (len(method_names)-1) / 2)
ax.set_yticklabels(param_names)
ax.set_xlabel('μ*')

# Логарифмическая шкала
ax.set_xscale('log')
ax.grid(axis='x', linestyle='--', alpha=0.5, which='both')

# Правильный формат оси
ax.xaxis.set_major_formatter(EngFormatter(sep=" "))

max_val = np.max(mu_stars) * 2
min_val = np.max([np.min(mu_stars), 1e-6]) / 2  # чтобы не уходило в ноль лог-шкалы
ax.set_xlim(min_val, max_val)

# 📦 Сдвигаем легенду вниз, НЕ используя tight_layout
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=len(method_names))

# Увеличиваем нижнее поле вручную
plt.subplots_adjust(bottom=0.2)

plt.show()
