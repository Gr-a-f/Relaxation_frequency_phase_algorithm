# %%
# %load_ext autoreload 
# %autoreload 2

import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(project_root)

import numpy as np
import pandas as pd
from numpy import array
from numpy import array, arange, abs as np_abs
from numpy.fft import rfft, rfftfreq
from math import sin, pi
from scipy import signal
import matplotlib.pyplot as plt

import importlib
import model as md
import view as vw

importlib.reload(md)
importlib.reload(vw)

from model.relevant_methods import phase_methods
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# c:\Users\Артем\Desktop\Вуз\Аспирантура\Диссертация\Алгоритм\Relaxation_frequency_phase_algorithm

# %%
U_path = os.path.join(project_root, "data","microcap", "U.CSV")
I_path= os.path.join(project_root, "data","microcap", "I.CSV")

t,U = md.make_microcap_data_list(U_path)
t,I = md.make_microcap_data_list(I_path)

#U=md.adc_quantize(U,14,5)
#I=md.adc_quantize(I,14,5)

# %%
F,V = md.get_spectrum3(t,U)

F_peak_calc = F[np.argmax(V)]
T=1/F_peak_calc

T_counts=md.convert_to_counts(t,T)
window=T_counts*1

fs = 1 / np.mean(np.diff(t)) 
vw.show_I_U_3(t,I,U,0,window)

# %%
t_f, U_f=md.filter_butter_bandpass(t,U,F_peak_calc,200e3,2)
t_f, I_f=md.filter_butter_bandpass(t,I,F_peak_calc,200e3,2)

#U_f=U
#I_f=I
#t_f=t

#vw.show_I_U_3(t_f,I_f, U_f,0,window)

# %%
for i in range(0,len(phase_methods),1):
    phase=phase_methods[i](t_f, I_f,U_f, F_peak_calc)
    print(phase_methods[i].__name__)
    print (" phase extimated=",phase)
# Out:
# get_phase_MP
#  phase extimated= 23.074104514952296
# get_phase_ZCRR
#  phase extimated= 24.01684741640947
# get_phase_FFT
#  phase extimated= 23.991529414293016
# get_phase_HB
#  phase extimated= 23.856405857380594
# get_phase_XCOR
#  phase extimated= 24.110168886808655
# get_phase_LI
#  phase extimated= 23.98397245987502
# get_phase_SWFR
#  phase extimated= 24.27722166653524

# %%
phase_real=md.get_phase_RC_real(444e3,400,400e-12)
phase_real
# Out:
# 24.05395321063361

# %%
for i in range(0,len(phase_methods),1):
    phase=phase_methods[i](t_f, I_f,U_f, F_peak_calc)
    print(phase_methods[i].__name__)
    print (" phase error",phase-phase_real)
# Out:
# get_phase_MP
#  phase error 4.56520141947221
# get_phase_ZCRR
#  phase error 5.507944320929383
# get_phase_FFT
#  phase error 5.48262631881293
# get_phase_HB
#  phase error 5.3475027619005076
# get_phase_XCOR
#  phase error 5.601265791328569
# get_phase_LI
#  phase error 5.475069364394933
# get_phase_SWFR
#  phase error 5.768318571055154
