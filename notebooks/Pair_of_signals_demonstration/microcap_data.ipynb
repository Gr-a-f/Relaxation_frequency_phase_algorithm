# %%
# %load_ext autoreload 
# %autoreload 2

import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(project_root)

import numpy as np
import pandas as pd
from numpy import array
from numpy import array, arange, abs as np_abs
from numpy.fft import rfft, rfftfreq
from math import sin, pi
from scipy import signal
import matplotlib.pyplot as plt

import importlib
import model as md
import view as vw

importlib.reload(md)
importlib.reload(vw)

from model.relevant_methods import phase_methods
# Out:
# c:\Users\Артем\Desktop\Вуз\Аспирантура\Диссертация\Алгоритм\Relaxation_frequency_phase_algorithm

# %%
U_path = os.path.join(project_root, "data","microcap", "U.CSV")
I_path= os.path.join(project_root, "data","microcap", "I.CSV")

t,U = md.make_microcap_data_list(U_path)
t,I = md.make_microcap_data_list(I_path)

#U=md.adc_quantize(U,14,5)
#I=md.adc_quantize(I,14,5)

# %%
F,V = md.get_spectrum3(t,U)

F_peak_calc = F[np.argmax(V)]
T=1/F_peak_calc

T_counts=md.convert_to_counts(t,T)
window=T_counts*1

fs = 1 / np.mean(np.diff(t)) 
vw.show_I_U_3(t,I,U,0,window)

# %%
t_f, U_f=md.filter_butter_bandpass(t,U,F_peak_calc,200e3,2)
t_f, I_f=md.filter_butter_bandpass(t,I,F_peak_calc,200e3,2)

#U_f=U
#I_f=I
#t_f=t

#vw.show_I_U_3(t_f,I_f, U_f,0,window)

# %%
for i in range(0,len(phase_methods),1):
    phase=phase_methods[i](t_f, I_f,U_f, F_peak_calc)
    print(phase_methods[i].__name__)
    print (" phase extimated=",phase)
# Out:
# get_phase_MP
#  phase extimated= 34.71585758883771
# get_phase_ZCRR
#  phase extimated= 35.42891369127568
# get_phase_FFT
#  phase extimated= 35.17764410863035
# get_phase_HB
#  phase extimated= 35.17356257755321
# get_phase_XCOR
#  phase extimated= 35.39415588317016
# get_phase_LI
#  phase extimated= 35.190942869984056
# get_phase_SWFR
#  phase extimated= 35.373874941346

# %%
phase_real=md.get_phase_RC_real(444e3,400,400e-12)
phase_real
# Out:
# 24.05395321063361

# %%
for i in range(0,len(phase_methods),1):
    phase=phase_methods[i](t_f, I_f,U_f, F_peak_calc)
    print(phase_methods[i].__name__)
    print (" phase error",phase-phase_real)
# Out:
# get_phase_MP
#  phase error 10.661904378204099
# get_phase_ZCRR
#  phase error 11.374960480642073
# get_phase_FFT
#  phase error 11.123690897996745
# get_phase_HB
#  phase error 11.119609366919605
# get_phase_XCOR
#  phase error 11.340202672536549
# get_phase_LI
#  phase error 11.136989659350448
# get_phase_SWFR
#  phase error 11.319921730712394
