# %%
# %load_ext autoreload
# %autoreload 2

import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(project_root)

import math
import numpy as np
import pandas as pd
from numpy import array
from numpy import array, arange, abs as np_abs
from numpy.fft import rfft, rfftfreq
from math import sin, pi
from scipy import signal
import matplotlib.pyplot as plt

import model as md
import view as vw

from model.relevant_methods import phase_methods
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# c:\Users\Артем\Desktop\Вуз\Аспирантура\Диссертация\Алгоритм\Relaxation_frequency_phase_algorithm

# %%
duration = 100e-6
F_main_real=440e3
fs=F_main_real*10

t = np.linspace(0, duration, int(duration * fs))  
U = np.sin(2 * np.pi * F_main_real * t)

# %%
R= 50
C= 475e-12
t,I= md.RC_transfer(t,U,R,C)

# %%
F,V = md.get_spectrum3(t,U)

F_peak_calc = F[np.argmax(V)]
T=1/F_peak_calc

T_counts=md.convert_to_counts(t,T)

phase_real=md.get_phase_RC_real(F_peak_calc, R,C)
phase_real_graph= np.full(len(t), phase_real)

# %%
vw.show_I_U_3(t,I,U)

# %%
for i in range(0,len(phase_methods),1):
    phase=phase_methods[i](t, I, U, F_peak_calc)
    print(phase_methods[i].__name__)
    print (" phase extimated=",phase)

print("Phase real=",phase_real)
# Out:
# get_phase_MP
#  phase extimated= 3.650929745304836
# get_phase_ZCRR
#  phase extimated= 3.452666925485609
# get_phase_FFT
#  phase extimated= 3.513813891801652
# get_phase_HB
#  phase extimated= 3.513917790246968
# get_phase_XCOR
#  phase extimated= 3.5194933120844745
# get_phase_LI
#  phase extimated= 3.512618478042622
# get_phase_SWFR
#  phase extimated= 3.52004951041107
# Phase real= 3.756421872730858
